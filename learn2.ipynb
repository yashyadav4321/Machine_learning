# %%
class MeraLR:
    def __init__(self):
        self.m=None
        self.b=None

    def fit(self,X_train,y_train):
        num = 0
        den = 0

        for i in range(X_train.shape[0]): #X_train.shape[0] points to all the rows
             num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
             den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))
        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print(self.m)
        print(self.b)

    def predict(self,X_test):
        print(X_test)
        return self.m * X_test + self.b

import numpy as np
import pandas as pd

df=pd.read_csv('placement.csv')
df.head()

X=df.iloc[:,0].values #- here we can take X,s data as it is in 1-D as we are not using library this time
y=df.iloc[:,1].values
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split as tts
X_train,X_test,y_train,y_test=tts(X,y,test_size=0.2,random_state=2)
X_train.shape
# Out:
# (160,)

# %%
lr=MeraLR()
lr.fit(X_train,y_train)
# Out:
# 0.5579519734250721
# -0.8961119222429152

# %%
print(lr.predict(X_test[0]))
# Out:
# None
