# %%
# Finding both m and b at a time using Gradient Descent in Linear Regression 

from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20)

plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X,y)
print("coeff=",lr.coef_)
print("intercept=",lr.intercept_)
# Out:
# coeff= [54.06468653]
# intercept= -2.0894322977516833

# %%
class GDRegressor:

    def __init__(self,learning_rate,epochs):
        self.m = 100 #can be any random value
        self.b = -120 #can be any random value
        self.lr = learning_rate
        self.epochs = epochs

    def fit(self,X,y):
        # calcualte the b using GD
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())

            self.b = self.b - (self.lr * loss_slope_b)
            self.m = self.m - (self.lr * loss_slope_m)
        print(self.m,self.b)

# %%
gd = GDRegressor(0.001,100)

gd.fit(X,y)
# Out:
# 54.064687086509046 -2.089432575329394
